# %% [markdown]
# # 07 試寫10個數字，使用 streamlit run 06_prediction_web.py，檢查正確的個數

# %%
from IPython.display import Image
Image('0.png', width=600)

# %%
from IPython.display import Image
Image('1.png', width=600)

# %%
from IPython.display import Image
Image('2.png', width=600)

# %%
from IPython.display import Image
Image('3.png', width=600)

# %%
from IPython.display import Image
Image('4.png', width=600)

# %%
from IPython.display import Image
Image('5.png', width=600)

# %%
from IPython.display import Image
Image('6.png', width=600)

# %%
from IPython.display import Image
Image('7.png', width=600)

# %%
from IPython.display import Image
Image('8.png', width=600)

# %%
from IPython.display import Image
Image('9.png', width=600)

# %% [markdown]
# ## 結論:
# ## 0-9數字只成功辨識出1、2、3共3個數字，而且4-9數字與辨識出的數字差異極大，表示此模型仍需加入更多資料訓練，提高模型辨識正確數字之正確率
